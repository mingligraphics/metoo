# %%
import pandas as pd
import datetime

# %%
df = pd.read_csv('metoo.csv', parse_dates = ['Date when case first revealed'])

# %%
# df2 = pd.read_csv('case_data.csv')
# df2["Date when case first revealed"] = pd.to_datetime(df2["Date when case first revealed"]).dt.strftime('%Y-%m-%d')

# %%
# df2.head()

# %%
df = df.sort_values(by='Date when case first revealed')

# %%
df.to_csv('metoo_time_sorted.csv',index=False)

# %%
df = pd.read_csv('MeToo_data_time_sorted.csv', parse_dates = ['Date when case first revealed'])

# %%
df['Date when case first revealed'].value_counts()
# Out:
# 2018-07-26    9
# 2018-07-25    8
# 2018-07-29    4
# 2018-07-23    3
# 2018-07-24    3
# 2018-07-28    2
# 2018-07-27    2
# 2018-08-01    1
# 2018-01-01    1
# 2018-08-02    1
# 2018-04-11    1
# 2018-04-05    1
# 2018-03-10    1
# 2018-06-25    1
# 2018-07-31    1
# 2018-07-20    1
# 2018-12-29    1
# 2018-04-16    1
# 2018-08-09    1
# 2018-04-25    1
# 2018-08-12    1
# 2018-04-13    1
# 2018-06-30    1
# 2018-09-20    1
# 2018-01-11    1
# 2018-02-05    1
# 2018-03-27    1
# 2018-10-19    1
# 2018-04-28    1
# 2018-08-31    1
# Name: Date when case first revealed, dtype: int64

# %%
def f(df):
    df = df.copy()
    df['year'] = pd.DatetimeIndex(df['Date when case first revealed']).year
    df['month'] = pd.DatetimeIndex(df['Date when case first revealed']).month
    df['day'] = pd.DatetimeIndex(df['Date when case first revealed']).day
    return df

# %%
f(df).month.value_counts()
# Out:
# 7     33
# 4      6
# 8      5
# 6      2
# 3      2
# 1      2
# 12     1
# 10     1
# 9      1
# 2      1
# Name: month, dtype: int64

# %%
f(df).groupby(['month','Location']).count()
# Out:
#                             Date when case first revealed  Date of case  \
# month Location
# 1     Beijing                                           2             2
# 2     Beijing                                           1             1
# 3     Shanghai                                          1             0
#       The U.S.                                          1             1
# 4     Beijing                                           1             0
#       Beijing/Nanjing                                   2             2
#       Guangzhou, Guangdong                              1             0
#       Shanghai                                          1             0
#       Zhengzhou, Henan                                  1             1
# 6     Linyi, Shandong                                   1             0
#       Qingyang, Gansu                                   1             1
# 7     Beijing                                          13            10
# ...

# %%
df['Number of Victims'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-2ce1f442c010> in <module>
# ----> 1 df['Number of Victims'].astype(float)
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5689             # else, only a single dtype is given
#    5690             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5691                                          **kwargs)
#    5692             return self._constructor(new_data).__finalize__(self)
#    5693
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/internals/managers.py in astype(self, dtype, **kwargs)
#     529
#     530     def astype(self, dtype, **kwargs):
# --> 531         return self.apply('astype', dtype=dtype, **kwargs)
#     532
#     533     def convert(self, **kwargs):
#
# ...
